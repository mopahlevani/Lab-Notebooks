# %% [markdown]
# <a href="https://colab.research.google.com/github/mopahlevani/Lab-Notebooks/blob/main/DLVO_Theory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Numerical problem DLVO theory: \\
# Play with your favorite function tracing software to study the sum of the Van der Waals
# $U_{(D)} = a_{(σ)} e^{−κD}$ and electrostatic $U_{(D)}=\frac{−A}{π}\frac{1}{ 12 D^{2}}$ potential terms describing the interaction
# between colloids in a solution.
# Find parameters for which the solution is stable, with a secondary minimum, and parameters for
# which one expect to observe coagulation.

# %%
import numpy as np
import matplotlib.pyplot as plt

a = 3
k = 1
C = 1e-20  # Hamaker constant (J)
R = 100e-9  # Particle radius (m)
psi_0 = 0.05  # Surface potential (V)
lambda_D = 10e-9  # Debye length (m)
epsilon_r = 78.5  # Relative permittivity of water
epsilon_0 = 8.854e-12  # Permittivity of free space (F/m)

def ES(D):
  return np.pi * epsilon_r * epsilon_0 * R * psi_0**2 * np.exp(-D / lambda_D)

def VDW(D):
  #return (np.pi * C * 1**2) / (6 * D**2)
  return - (np.pi * C * R**2) / (6 * D**2)


def EV(D):
  return c / D**12

n = np.linspace(1e-9,5e-8,1000)

DLVO = VDW(n) + ES(n) #+ EV(n)
plt.plot(n,ES(n),color='green', label = 'Electrostatic Potential')
plt.plot(n,VDW(n), color='red', label = 'Van der Waals Potential')
#plt.plot(n,EV(n), color='yellow', label = 'Excluded Volume')
plt.plot(n, DLVO, color='blue', label = 'DLVO')
plt.xlabel('Distance')
plt.ylabel('Potential Energy')
plt.xscale('log')
plt.grid(True)
plt.legend()
plt.show()
